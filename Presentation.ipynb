# %% [markdown]
# Sopron University is a public university located in the town of Sopron, western borders of Hungary.
# ![Sopron.png](Sopron.png "Sopron University")
#
# # Scientific results obtained during the stay
# ## Definitions
# ### Permutations
# ```latex
#
# \begin{block}{}
# A \textbf{Permutation} $\sigma$ of the set $[n]=\{1,2,\dots,n\}$ is a rearrangement (linear ordering) of its elements.
# \end{block}
# ```
# ### Partitions
#
# ```latex
# \begin{block}{}
# A \textbf{partition} $\pi$ of the set $[n]=\{1,2,\dots,n\}$ into $k$ parts is a distribution of its elements into $k$ nonempty disjoint subsets $b_1,b_2,\dots,b_k$ called \textit{blocks}. We denote
# \begin{equation*}
# \pi([n])=b_1|b_2|\dots|b_k,
# \end{equation*}
# with $\bigcup_{i=1}^{k}b_i=[n]$ and $b_i \neq \emptyset$, for $\ i \in \{1,\dots,k\}$.
# \end{block}
# ```
# **Example**
#
# ### Stirling numbers of the second kind
#
# \begin{block}{}
#   \textbf{Stirling numbers of the second kind}, denoted $ {n \brace k}$, count the number of all partitions of $[n]$ having exactly $k$ blocks.
# \end{block}
#
# ## Ordered Bell numbers
# ###
# ```latex
# The Ordered Bell numbers $w_n$ counts the total number of ordered partitions of the set $[n]$. The first few values of $w_n$ are
# $$\lbrace w_n \rbrace_{n \geq 0}=\{1,1,3,13,75,541,4683,47293,545835,7087261,\dots\}.$$
#
# referenced under the number \alert{(OEIS A000670)}  in the On-Line Encyclopedia of Integer Sequences.
#
#
# ```
#
# - Justify the Mathematical definition
# - History (Euler, withwort, Gross, Qinj Zou)
# -
#
#
# ## Motivation of our work
# In 2020, in a joined work with Pr. Belbachir (USTHB) and Pr. Nemeth (Sopron Univ.), we asked the question, **What is the total number of the ordered partitions without
# fixed blocks (deranged blocks)**,
# this question lead us to publish a the following paper
# - Belbachir, H., Dj., Y. & Németh, L. (2022). "The deranged Bell numbers". Mathematica Slovaca (accepted).
# Motivated by this work, and the fact that ordered Bell numbers are the number of permutations of blocks, we tried to find another special permutation but this time why do not try link the historical Fibonacci and Lucas number to the set partition numbers, so a second joined work with Dr. Mehdaoui (NHSM) and  Professors Nemeth and Szalay (Sopron Univ.) we asked the question **What is the total number of the ordered partitions such that each block will be in his position or the position of one of his adjacent blocks (deranged blocks)**.
#
# That's give as the new type of ordered partitions, which called "Fibonacci ordered partitions", defined by
#
# *****
#
# ## Methodology
# - Enumeratting the first instances of the problem and understand the small instance of  the problem
# - Try to generalise the result for any size of the problem
# - Try to proof the results, and check them using mathematical computing softwares
# ## Some Results
# -
# -
# -
# -
# # Pedagogical practices observed during the stay
#
# - During my visit to the hosting university, the students were on vacation due to an energy crisis in the country, only PhD students were still working on their research projects during this time.
#
# - Several meetings were taking place between staff members to identify areas for improvement and discuss potential solutions to the challenges faced by the department.
#
# - It was clear that they were passionate about their research works.
#
# # New teaching method
#
# - During my visit to Sopron university, after a discussion with stuff members, there were two primary teaching methods utilized by the department of mathematics and computer sciences:
#     1. The first was the classical teaching method, which involved in-person lectures and traditional classroom instruction.
#
#     2. The second was the use of new technologies, such as online teaching software, to enhance the learning experience for students.
#
# - This hybrid approach to teaching was essential in addressing the evolving needs of the modern workforce and equipping students with the skills and knowledge necessary to succeed .
